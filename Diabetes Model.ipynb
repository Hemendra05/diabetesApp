# %%
import pandas as pd

# %%
dataset = pd.read_csv('pima-indians-diabetes.data.csv', header = None)

# %%
dataset
# Out:
#       0    1   2   3    4     5      6   7  8
# 0     6  148  72  35    0  33.6  0.627  50  1
# 1     1   85  66  29    0  26.6  0.351  31  0
# 2     8  183  64   0    0  23.3  0.672  32  1
# 3     1   89  66  23   94  28.1  0.167  21  0
# 4     0  137  40  35  168  43.1  2.288  33  1
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 763  10  101  76  48  180  32.9  0.171  63  0
# 764   2  122  70  27    0  36.8  0.340  27  0
# 765   5  121  72  23  112  26.2  0.245  30  0
# 766   1  126  60   0    0  30.1  0.349  47  1
# 767   1   93  70  31    0  30.4  0.315  23  0
#
# [768 rows x 9 columns]

# %%
dataset.columns
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6, 7, 8], dtype='int64')

# %%
y = dataset[8]

# %%
X = dataset[[0,1,2,3,4,5,6,7]]

# %%
from keras.models import Sequential

# %%
from keras.layers import Dense

# %%
from keras.optimizers import Adam

# %%
model = Sequential()

# %%
model.add(Dense(units=12, input_dim=8, activation='relu'))

# %%
model.add(Dense(units=8,  activation='relu'))

# %%
model.add(Dense(units=1,  activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 12)                108
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# ...
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics = ['accuracy'])

# %%
model.fit(X, y, epochs=300)
# Out:
# Epoch 1/300
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3791 - accuracy: 0.8099
# Epoch 2/300
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3773 - accuracy: 0.8099
# Epoch 3/300
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3770 - accuracy: 0.8151
# Epoch 4/300
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3770 - accuracy: 0.8112
# Epoch 5/300
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3765 - accuracy: 0.8138
# Epoch 6/300
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3769 - accuracy: 0.8138
# Epoch 7/300
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3762 - accuracy: 0.8138
# Epoch 8/300
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3763 - accuracy: 0.8125
# Epoch 9/300
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3763 - accuracy: 0.8151
# Epoch 10/300
# ...

# %%
import matplotlib

# %%
loss = pd.DataFrame(model.history.history)

# %%
loss.plot()
# Out:
# <AxesSubplot:>

# %%
model.predict([[8,125,96,0,0,0.0,0.232,54]])
# Out:
# array([[0.05280572]], dtype=float32)

# %%
model.predict([[10,101,76,48,180,32.9,0.171,63]])
# Out:
# array([[0.23863792]], dtype=float32)

# %%
model.predict([[0,137,40,35,168,43.1,2.288,33]])
# Out:
# array([[0.8018069]], dtype=float32)

# %%
model.predict([[5,121,72,23,112,26.2,0.24,530]])
# Out:
# array([[0.]], dtype=float32)

# %%
model.predict([[6,148,72,35,0,33.6,0.627,50]])
# Out:
# array([[0.8735717]], dtype=float32)

# %%
model.save("diabetes_model.h5")
